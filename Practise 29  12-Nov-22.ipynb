# %% [markdown]
# # Ham & Spam Data Preprocessing and Purification

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding='ISO-8859-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# 1. Data Cleaning
# 2. Exploratory Data Analysis(EDA)
# 3. Text Preprocessing & Purification

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# a. Drop Null Columns

# %%
df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True,axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# b. Renaming Columns

# %%
df=df.rename(columns={'v1':'target','v2':'text'})
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# c. Binary Classification On Target

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
df.target=encoder.fit_transform(df.target)

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# d. Removing Null Values

# %%
df.isnull().sum()   #No Null Values
# Out:
# target    0
# text      0
# dtype: int64

# %% [markdown]
# e. Removing Dublicate Values

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5169, 2)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 2. Exploratory Data Analysis(EDA)

# %%
value_counts=df.target.value_counts()
value_counts
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %% [markdown]
# a. PIE Chart Plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(value_counts,labels=['ham','spam'],autopct='%0.2f')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# b. Seperation of number of Words, Characters and Sentences

# %%
df['no_of_characters']=df['text'].apply(len)
df.head()
# Out:
#    target                                               text  no_of_characters
# 0       0  Go until jurong point, crazy.. Available only ...               111
# 1       0                      Ok lar... Joking wif u oni...                29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...               155
# 3       0  U dun say so early hor... U c already then say...                49
# 4       0  Nah I don't think he goes to usf, he lives aro...                61

# %%
df['no_of_words']=df['text'].apply(lambda x:len(x.split(' ')))
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    no_of_characters  no_of_words
# 0               111           20
# 1                29            6
# 2               155           28
# 3                49           11
# 4                61           13

# %%
df["no_of_sentences"]=df['text'].apply(lambda x: len(x.split('.')))
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    no_of_characters  no_of_words  no_of_sentences
# 0               111           20                9
# 1                29            6                7
# 2               155           28                2
# 3                49           11                7
# 4                61           13                1

# %% [markdown]
# c. Words Tokenization

# %%
import nltk

# %%
nltk.download('punkt') #using for tokenization of words and sentences etc...
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['words_tokenization']=df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    no_of_characters  no_of_words  no_of_sentences  words_tokenization
# 0               111           20                9                  24
# 1                29            6                7                   8
# 2               155           28                2                  37
# 3                49           11                7                  13
# 4                61           13                1                  15

# %%
df['sentences_tokenization']=df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    no_of_characters  no_of_words  no_of_sentences  words_tokenization  \
# 0               111           20                9                  24
# 1                29            6                7                   8
# 2               155           28                2                  37
# 3                49           11                7                  13
# 4                61           13                1                  15
#
#    sentences_tokenization
# 0                       2
# 1                       2
# 2                       2
# 3                       1
# 4                       1

# %%
# stats behind all new added columns
df[['no_of_characters','words_tokenization','sentences_tokenization']].describe()
# Out:
#        no_of_characters  words_tokenization  sentences_tokenization
# count       5169.000000         5169.000000             5169.000000
# mean          78.977945           18.453279                1.947185
# std           58.236293           13.324793                1.362406
# min            2.000000            1.000000                1.000000
# 25%           36.000000            9.000000                1.000000
# 50%           60.000000           15.000000                1.000000
# 75%          117.000000           26.000000                2.000000
# max          910.000000          220.000000               28.000000

# %%
# stats behind all new added columns in ham
df[df['target']==0].describe()
# Out:
#        target  no_of_characters  no_of_words  no_of_sentences  \
# count  4516.0       4516.000000  4516.000000      4516.000000
# mean      0.0         70.459256    14.259743         2.916519
# std       0.0         56.358207    11.231781         2.638732
# min       0.0          2.000000     1.000000         1.000000
# 25%       0.0         34.000000     7.000000         1.000000
# 50%       0.0         52.000000    11.000000         2.000000
# 75%       0.0         90.000000    19.000000         4.000000
# max       0.0        910.000000   171.000000        42.000000
#
#        words_tokenization  sentences_tokenization
# count         4516.000000             4516.000000
# mean            17.120903                1.799601
# std             13.493725                1.278465
# min              1.000000                1.000000
# 25%              8.000000                1.000000
# 50%             13.000000                1.000000
# 75%             22.000000                2.000000
# max            220.000000               28.000000

# %%
# stats behind specifiied columns in ham
df[df['target']==0][['no_of_characters','words_tokenization','sentences_tokenization']].describe()
# Out:
#        no_of_characters  words_tokenization  sentences_tokenization
# count       4516.000000         4516.000000             4516.000000
# mean          70.459256           17.120903                1.799601
# std           56.358207           13.493725                1.278465
# min            2.000000            1.000000                1.000000
# 25%           34.000000            8.000000                1.000000
# 50%           52.000000           13.000000                1.000000
# 75%           90.000000           22.000000                2.000000
# max          910.000000          220.000000               28.000000

# %%
# stats behind all new added columns in spam
df[df['target']==1].describe()
# Out:
#        target  no_of_characters  no_of_words  no_of_sentences  \
# count   653.0        653.000000   653.000000       653.000000
# mean      1.0        137.891271    23.728943         3.055130
# std       0.0         30.137753     5.985799         1.725848
# min       1.0         13.000000     2.000000         1.000000
# 25%       1.0        132.000000    22.000000         2.000000
# 50%       1.0        149.000000    25.000000         3.000000
# 75%       1.0        157.000000    28.000000         4.000000
# max       1.0        224.000000    35.000000        14.000000
#
#        words_tokenization  sentences_tokenization
# count          653.000000              653.000000
# mean            27.667688                2.967841
# std              7.008418                1.483201
# min              2.000000                1.000000
# 25%             25.000000                2.000000
# 50%             29.000000                3.000000
# 75%             32.000000                4.000000
# max             46.000000                8.000000

# %%
# stats behind specifiied columns in spam
df[df['target']==1][['no_of_characters','words_tokenization','sentences_tokenization']].describe()
# Out:
#        no_of_characters  words_tokenization  sentences_tokenization
# count        653.000000          653.000000              653.000000
# mean         137.891271           27.667688                2.967841
# std           30.137753            7.008418                1.483201
# min           13.000000            2.000000                1.000000
# 25%          132.000000           25.000000                2.000000
# 50%          149.000000           29.000000                3.000000
# 75%          157.000000           32.000000                4.000000
# max          224.000000           46.000000                8.000000

# %% [markdown]
# d. Histogram Plotting

# %%
import seaborn as sns

# %%
plt.figure(figsize=(14,7))
sns.histplot(df[df['target']==0]['no_of_characters'],color='Green')
sns.histplot(df[df['target']==1]['no_of_characters'],color='Red')
# Out:
# <AxesSubplot:xlabel='no_of_characters', ylabel='Count'>

# %%
plt.figure(figsize=(14,7))
sns.histplot(df[df['target']==0]['words_tokenization'],color='black')
sns.histplot(df[df['target']==1]['words_tokenization'],color='orange')
# Out:
# <AxesSubplot:xlabel='words_tokenization', ylabel='Count'>

# %%
plt.figure(figsize=(14,7))
sns.histplot(df[df['target']==0]['sentences_tokenization'],color='BLUE')
sns.histplot(df[df['target']==1]['sentences_tokenization'],color='maroon')
# Out:
# <AxesSubplot:xlabel='sentences_tokenization', ylabel='Count'>

# %% [markdown]
# e. Pair Plotting

# %%
sns.pairplot(df,hue='target')  #Pair Plotting defines the correlation between ham & spam in target column

# %%
df.corr() #correlation of every row with another column
# Out:
#                           target  no_of_characters  no_of_words  \
# target                  1.000000          0.384717     0.281818
# no_of_characters        0.384717          1.000000     0.974219
# no_of_words             0.281818          0.974219     1.000000
# no_of_sentences         0.018118          0.428390     0.410364
# words_tokenization      0.262984          0.965770     0.979444
# sentences_tokenization  0.284901          0.638143     0.642457
#
#                         no_of_sentences  words_tokenization  \
# target                         0.018118            0.262984
# no_of_characters               0.428390            0.965770
# no_of_words                    0.410364            0.979444
# no_of_sentences                1.000000            0.465198
# words_tokenization             0.465198            1.000000
# sentences_tokenization         0.423312            0.684541
#
#                         sentences_tokenization
# target                                0.284901
# no_of_characters                      0.638143
# no_of_words                           0.642457
# no_of_sentences                       0.423312
# words_tokenization                    0.684541
# sentences_tokenization                1.000000

# %%
df['target'].corr(df['words_tokenization'])
# Out:
# 0.2629835742852427

# %%
df['words_tokenization'].corr(df['sentences_tokenization'])
# Out:
# 0.6845408831149301

# %%
sns.heatmap(df.corr(),annot=True)    #heatmap shows the correlation of each column with another columns in suitable form
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# - convert all text in lower case
# - Tokenization
# - Remove Special characters
# - Removing stopwords & punctuation
# - Stemming

# %%
#Stopwords

nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Punctuations

import string
punctuations=string.punctuation
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#Stemming

from nltk.stem.porter import PorterStemmer
stemming=PorterStemmer()
stemming.stem('beautiful')
# Out:
# 'beauti'

# %%
# Function for Text Transformation

def text_transformation(text):
    
    #changing text in lower case
    text=text.lower()
    
    lst=[]
    
    #Tokenization
    text=nltk.word_tokenize(text)
    
    #Removing special characters
    
    for i in text:
        if i.isalnum():
            lst.append(i)
    text=lst[:]
    lst.clear()
    
    #Removing stopwords & Punctuations
    
    for i in text:
        if(i not in stopwords) and(i not in punctuations):
            lst.append(i)
    text=lst[:]
    lst.clear()
    
    #Stemming
    
    for i in text:
        lst.append(stemming.stem(i))
    
    return " ".join(lst)

# %%
#testing of text transformation function

text_transformation('I am Abdul Rehman I am Realizing ,,,;;;///')
# Out:
# 'abdul rehman realiz'

# %%
#Applying function on text column

df['transformed_text']=df['text'].apply(text_transformation)
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    no_of_characters  no_of_words  no_of_sentences  words_tokenization  \
# 0               111           20                9                  24
# 1                29            6                7                   8
# 2               155           28                2                  37
# 3                49           11                7                  13
# 4                61           13                1                  15
#
#    sentences_tokenization                                   transformed_text
# 0                       2  go jurong point crazi avail bugi n great world...
# 1                       2                              ok lar joke wif u oni
# 2                       2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                       1                u dun say earli hor u c alreadi say
# 4                       1               nah think goe usf live around though

# %% [markdown]
# # Word Cloud

# %%
# %pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\user\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
wc=WordCloud(width=800,height=400,max_font_size=100,background_color='white')

# %%
spam_word_cloud=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

plt.figure(figsize=(14,7))
plt.imshow(spam_word_cloud)

# %%
wc=WordCloud(width=800,height=400,max_font_size=100,background_color='white')

# %%
ham_word_cloud=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))
plt.figure(figsize=(14,7))
plt.imshow(ham_word_cloud)
